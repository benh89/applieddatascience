# %% [markdown]
# # Applied Data Science Capstone Project
# ## The notebook is to be mainly used as developing environment for the IBM data science capstone project

# %%
import pandas as pd
import numpy as np

# %%
print('Hell Capstone Project Course!')
# Out:
# Hell Capstone Project Course!
