# %% [markdown]
# ### Performance Monitoring

# %%
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# Some important pieces of performance monitoring are shown in the following tree:
#
# ```
# ├── app.py
# ├── Dockerfile
# ├── model.py
# ├── README.rst
# ├── requirements.txt
# ├── run-tests.py
# ├── templates
# │   ├── base.html
# │   ├── dashboard.html
# │   ├── index.html
# │   └── running.html
# └── unittests
#     ├── ApiTests.py
#     ├── __init__.py
#     ├── ModelTests.py
# ```

# %%
##!python ./unittests/LoggerTests.py

# %%
# !python ./unittests/LoggerTests.ipynb

# %%
# !python ./unittests/ApiTests.py

# %% [markdown]
# Running Tests...

# %%
# !python run-tests.py
